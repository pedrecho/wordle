# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrecho/wordle/blob/main/wordle_pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
dictionary = open('dictionary.txt', 'r').read().split('\n')

# %%
dict1 = dictionary
letters = []
required = []
for i in range(5):
  letters.append([])
  for l in range(32):
    letters[i].append(chr(l + ord('а')))
print(letters)
while True:
  dict2 = []
  s = random.choice(dict1)
  print(s)
  a = input()
  for i in range(5):
    if a[i] == '2':
      if s[i] not in required:
        required.append(s[i])
      letters[i] = s[i]
  for i in range(5):
    if a[i] == '1':
      if s[i] not in required:
        required.append(s[i])
      if s[i] in letters[i]:
        letters[i].remove(s[i])
    if a[i] == '0':
      for l in range(5):
        if len(letters[l]) != 1:
          if s[i] in letters[l]:
            letters[l].remove(s[i])
  print(letters)
  for i in dict1:
    word = i
    b = True
    for l in range(5):
      if word[l] not in letters[l]:
        b = False
    for l in required:
      if l not in word:
        b = False
    if b:
      dict2.append(word)
  dict1 = dict2
  print(len(dict1))
  print(dict1)
# Out:
# [['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']]
# гашиш
# 00000
# [['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']]
# 922
# ['бдеть', 'бедро', 'бекон', 'белек', 'белок', 'белый', 'белье', 'беляк', 'бензо', 'берет', 'бетон', 'блеск', 'блюдо', 'бобер', 'божок', 'бойня', 'боком', 'более', 'бомбо', 'бордо', 'борец', 'боров', 'борть', 'босой', 'босяк', 'бремя', 'бровь', 'броне', 'броня', 'брысь', 'брюхо', 'бубен', 'бубны', 'будет', 'будто', 'букет', 'букле', 'бульк', 'бурун', 'бурый', 'бутон', 'бутсы', 'бутуз', 'буфер', 'буфет', 'быдло', 'былой', 'былье', 'бытье', 'бычок', 'вброд', 'вверх', 'вволю', 'ввысь', 'вдвое', 'вдеть', 'вдоль', 'вдоль', 'ведро', 'вееро', 'везде', 'велюр', 'венец', 'венок', 'вепрь', 'вепсы', 'верфь', 'весло', 'весть', 'ветвь', 'ветер', 'ветро', 'вечер', 'вечно', 'вечор', 'вещун', 'веять', 'взвод', 'вздор', 'вздох', 'взлет', 'взнос', 'взрыв', 'взять', 'вкось', 'вкупе', 'влево', 'влечь', 'вмять', 'внове', 'вновь', 'внять', 'вовек', 'вовне', 'вовсе', 'вовсю', 'вождь', 'возле', 'возня', 'возок', 'волок', 'волос', 'волхв', 'вольт', 'вопль', 'ворон', 'ворот', 'ворох', 'вотум', 'вотще', 'впору', 'впрок', 'время', 'вроде', 'врозь', 'врыть', 'вслед', 'вслух', 'всход', 'всюду', 'всяко', 'втечь', 'второ', 'втрое', 'втуне', 'вчуже', 'въезд', 'въявь', 'выбор', 'вывод', 'вывоз', 'выдох', 'выезд', 'вызов', 'выкуп', 'вынос', 'выпот', 'вырез', 'выход', 'вычет', 'вялый', 'дверь', 'дебет', 'дебют', 'дележ', 'делец', 'демон', 'денно', 'десть', 'деюре', 'дзюдо', 'добре', 'добро', 'довод', 'дождь', 'дозор', 'докер', 'долой', 'домой', 'донец', 'донор', 'донос', 'досто', 'досыл', 'досье', 'доход', 'древо', 'древо', 'дрейф', 'дрель', 'дробь', 'дрожь', 'дрозд', 'дрянь', 'дубль', 'дубье', 'дупло', 'дурей', 'дурно', 'дутый', 'дутье', 'духом', 'дуэль', 'дыбом', 'дымок', 'дятел', 'евнух', 'ездок', 'ересь', 'желоб', 'желто', 'желчь', 'жердь', 'жерех', 'жерло', 'жесть', 'жетон', 'жокей', 'жупел', 'жучок', 'звено', 'зверо', 'зверь', 'звуко', 'здесь', 'зевок', 'зелье', 'земле', 'земля', 'земно', 'зерно', 'зерно', 'злеть', 'зреть', 'зубец', 'зубок', 'зыбун', 'келья', 'клерк', 'клест', 'клеть', 'клоун', 'кнехт', 'князь', 'ковер', 'кожух', 'козел', 'козлы', 'койот', 'кокон', 'кокос', 'колер', 'колея', 'колок', 'колос', 'колун', 'колье', 'кольт', 'комод', 'комок', 'конек', 'конец', 'конно', 'контр', 'конус', 'конюх', 'копер', 'копун', 'копыл', 'копье', 'кормо', 'короб', 'корье', 'косец', 'космо', 'космы', 'косой', 'кость', 'косяк', 'котел', 'кочет', 'кощей', 'кредо', 'креол', 'крепь', 'крест', 'крове', 'крово', 'кровь', 'кроль', 'кроме', 'кросс', 'крыло', 'крыть', 'кряду', 'ктото', 'кубок', 'кузен', 'кузов', 'кулек', 'кулон', 'культ', 'культ', 'кумыс', 'купец', 'купля', 'купол', 'купон', 'курды', 'курок', 'курсы', 'кусок', 'кутеж', 'куток', 'кутья', 'кухня', 'куцый', 'кучер', 'кювет', 'левый', 'лежмя', 'лезть', 'лемех', 'лемур', 'лепет', 'лесть', 'леток', 'летом', 'летун', 'лобок', 'ловец', 'ловля', 'ложно', 'ложок', 'локон', 'лопух', 'лоток', 'лотос', 'лохмы', 'лубок', 'лужок', 'лучок', 'лыжня', 'лысый', 'лычко', 'льяло', 'любой', 'люнет', 'лютня', 'лютый', 'медно', 'медяк', 'между', 'между', 'мелко', 'мелок', 'менее', 'место', 'место', 'месть', 'месяц', 'метео', 'метод', 'метод', 'метро', 'млеко', 'млеть', 'может', 'можно', 'мокко', 'молот', 'молох', 'мопед', 'мороз', 'моряк', 'мосол', 'мотня', 'моток', 'мотор', 'мохер', 'музей', 'муляж', 'мурло', 'мусор', 'мутно', 'мысль', 'мямля', 'мятеж', 'мятый', 'небез', 'небес', 'невод', 'невро', 'нежно', 'нейро', 'некто', 'немой', 'немцы', 'ненцы', 'несть', 'несун', 'нетто', 'нефте', 'нефть', 'нечет', 'нечто', 'новый', 'ножны', 'номер', 'норов', 'носок', 'ночью', 'нутро', 'нынче', 'нырок', 'обвод', 'обзор', 'обком', 'облом', 'обмен', 'обрез', 'оброк', 'обруб', 'обруч', 'обрыв', 'обряд', 'обувь', 'обуть', 'обход', 'объем', 'обыск', 'овоще', 'овощь', 'одеть', 'одурь', 'ожечь', 'оземь', 'озеро', 'озноб', 'оковы', 'около', 'около', 'окрол', 'октет', 'окунь', 'олень', 'олово', 'омлет', 'омуль', 'омыть', 'оплот', 'опоек', 'опрос', 'опять', 'орден', 'ордер', 'ореол', 'орлец', 'осень', 'осетр', 'особь', 'остов', 'остол', 'остро', 'ос ...
# скунс
# 00000
# [['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'п', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'п', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'п', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'п', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'д', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'п', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']]
# 311
# ['бдеть', 'бедро', 'белый', 'белье', 'берет', 'блюдо', 'бобер', 'более', 'бомбо', 'бордо', 'борец', 'боров', 'борть', 'бремя', 'бровь', 'брюхо', 'быдло', 'былой', 'былье', 'бытье', 'вброд', 'вверх', 'вволю', 'вдвое', 'вдеть', 'вдоль', 'вдоль', 'ведро', 'вееро', 'везде', 'велюр', 'вепрь', 'верфь', 'ветвь', 'ветер', 'ветро', 'вечер', 'вечор', 'веять', 'взвод', 'вздор', 'вздох', 'взлет', 'взрыв', 'взять', 'влево', 'влечь', 'вмять', 'вождь', 'возле', 'волхв', 'вольт', 'вопль', 'ворот', 'ворох', 'вотще', 'время', 'вроде', 'врозь', 'врыть', 'втечь', 'второ', 'втрое', 'въезд', 'въявь', 'выбор', 'вывод', 'вывоз', 'выдох', 'выезд', 'вызов', 'выпот', 'вырез', 'выход', 'вычет', 'вялый', 'дверь', 'дебет', 'дебют', 'дележ', 'делец', 'деюре', 'дзюдо', 'добре', 'добро', 'довод', 'дождь', 'дозор', 'долой', 'домой', 'доход', 'древо', 'древо', 'дрейф', 'дрель', 'дробь', 'дрожь', 'дрозд', 'дыбом', 'дятел', 'желоб', 'желто', 'желчь', 'жердь', 'жерех', 'жерло', 'зверо', 'зверь', 'зелье', 'земле', 'земля', 'злеть', 'зреть', 'левый', 'лежмя', 'лезть', 'лемех', 'лепет', 'летом', 'ловец', 'ловля', 'лохмы', 'льяло', 'любой', 'лютый', 'метео', 'метод', 'метод', 'метро', 'млеть', 'может', 'молот', 'молох', 'мопед', 'мороз', 'мотор', 'мохер', 'мямля', 'мятеж', 'мятый', 'обвод', 'обзор', 'облом', 'обрез', 'обрыв', 'обряд', 'обход', 'объем', 'овоще', 'овощь', 'одеть', 'ожечь', 'оземь', 'озеро', 'олово', 'омлет', 'омыть', 'оплот', 'опять', 'ордер', 'ореол', 'орлец', 'отбой', 'отбор', 'ответ', 'отвод', 'отдел', 'отдых', 'отель', 'отечь', 'отзыв', 'отлет', 'отпор', 'отрез', 'отрыв', 'отряд', 'отход', 'отцов', 'отчет', 'отъем', 'офорт', 'певец', 'пепел', 'перво', 'перед', 'перед', 'перец', 'петел', 'петля', 'пехом', 'племя', 'плеть', 'плечо', 'плодо', 'плоть', 'плыть', 'повод', 'подле', 'подол', 'поезд', 'позер', 'позже', 'позор', 'позыв', 'пойло', 'полет', 'полоз', 'полый', 'помет', 'помол', 'помор', 'попод', 'порез', 'порей', 'порой', 'порох', 'порою', 'порты', 'порыв', 'потом', 'потоп', 'поход', 'почем', 'почет', 'почто', 'предо', 'предъ', 'прель', 'преть', 'проем', 'прото', 'прочь', 'прыть', 'прядь', 'прямо', 'пырей', 'пятый', 'пятью', 'рдеть', 'ребро', 'ревмя', 'резец', 'ремез', 'репей', 'ретро', 'реять', 'робот', 'родео', 'ропот', 'ротор', 'рохля', 'рояль', 'рыбец', 'рябой', 'рядом', 'телец', 'тембр', 'тепло', 'тепло', 'терем', 'термо', 'тлеть', 'топор', 'топот', 'торец', 'торфо', 'тотем', 'трель', 'треть', 'трефы', 'тромб', 'трюмо', 'ферзь', 'формо', 'форте', 'фьорд', 'фьють', 'фюрер', 'хворь', 'хлебо', 'хлябь', 'хмель', 'хмырь', 'хобот', 'ходом', 'холод', 'холоп', 'хорей', 'хором', 'хохлы', 'хохол', 'хохот', 'хромо', 'цвето', 'цевье', 'целый', 'чейто', 'чепец', 'червь', 'черед', 'через', 'через', 'череп', 'чехол', 'чечет', 'чохом', 'чрево', 'чрезо', 'чтото', 'юдоль', 'юрьев']
# мопед
# 11020
# [['б', 'в', 'е', 'ж', 'з', 'й', 'л', 'о', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'е', 'ж', 'з', 'й', 'л', 'м', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], 'е', ['б', 'в', 'е', 'ж', 'з', 'й', 'л', 'м', 'о', 'р', 'т', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']]
# 3
# ['объем', 'омлет', 'отъем']
# омлет
# 21020
# ['о', ['б', 'в', 'е', 'ж', 'з', 'й', 'р', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], ['б', 'в', 'е', 'ж', 'з', 'й', 'м', 'о', 'р', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я'], 'е', ['б', 'в', 'е', 'ж', 'з', 'й', 'м', 'о', 'р', 'ф', 'х', 'ц', 'ч', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']]
# 1
# ['объем']
# объем
